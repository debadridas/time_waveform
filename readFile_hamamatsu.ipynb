# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_table('ave1/C1--HighPulse-in-100-out1700-an2100--00000.txt', sep="\t", names={'I','II'},
                   dtype = {'I': np.float64, 'II': np.float64}, usecols = [1,0], skiprows=5) 
df1 = pd.read_table('ave1/C1--HighPulse-in-100-out1700-an2100--00001.txt', sep="\t", names={'I','II'},
                   dtype = {'I': np.float64, 'II': np.float64}, usecols = [1,0], skiprows=5)
time = df['I'].tolist()
ampl = df['II'].tolist()
time1 = df1['I'].tolist()
ampl1 = df1['II'].tolist()
fig = plt.figure()
plt.plot(time,ampl)
plt.plot(time1,ampl1)
plt.grid('True')
# Out:
# <img src="data:image/png;base64,..." width="640">
